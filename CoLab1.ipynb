# %% [markdown]
# <a href="https://colab.research.google.com/github/AMC-74/Juypter_NoteBooks/blob/main/CoLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My First CoLab Notebook

# %%
Username = input("Name? ")
print(f"{Username}'s First Colab Notebook")
# Out:
# Name? Alan
# Alan's First Colab
